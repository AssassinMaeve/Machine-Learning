# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
house = fetch_california_housing()

# %%
X = house.data
Y = house.target

# %%
scaled = StandardScaler()

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,train_size=0.2, random_state=42)

# %%
X_train_scaled = scaled.fit_transform(X_train)
X_test_scaled = scaled.fit_transform(X_test)

# %%
model = KNeighborsRegressor(n_neighbors=5)

# %%
model.fit(X_train_scaled,Y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred = model.predict(X_test_scaled)

# %%
compDf = pd.DataFrame({"A":Y_test,"P":y_pred})

# %%
compDf
# Out:
#              A         P
# 0      0.47700  0.609600
# 1      0.45800  1.084800
# 2      5.00001  3.824402
# 3      2.18600  2.604600
# 4      2.78000  2.209200
# ...        ...       ...
# 16507  0.53900  0.706200
# 16508  0.93800  1.181800
# 16509  1.44300  1.545400
# 16510  1.54700  1.612600
# 16511  1.58800  1.762600
#
# [16512 rows x 2 columns]

# %%
msr = mean_squared_error(Y_test,y_pred)

# %%
r = r2_score(Y_test,y_pred)

# %%
msr
# Out:
# 0.4852829181663963

# %%
r
# Out:
# 0.6345589551195285

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(Y_test,y_pred,alpha = 0.5,color="red")
plt.ylabel("Actual house price")
plt.xlabel("Predected house price")
plt.grid(True)
